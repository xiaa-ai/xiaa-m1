# %%
# !git clone https://github.com/xiaa-ai/xiaa-m1.git
# %cd xiaa-m1
# !pip install sentencepiece datasets torch wandb -q

# %%
# Option A: upload data shards from a Hugging Face dataset cache
# Option B: stream directly from sources with the data pipeline
# Example (stream directly):
# !python scripts/prepare_data.py

# %%
# !python scripts/train.py --max_steps 50000 --batch_size 16

# %%
import shutil
shutil.copy("checkpoints/latest.pt", "/kaggle/working/xiaa_m1_latest.pt")

# %% [markdown]
# ## Resume Instructions
#
# 1. Put your previous checkpoint at `checkpoints/latest.pt`.
# 2. Re-run training with `python scripts/train.py --max_steps 50000 --batch_size 16 --resume`.
# 3. The script auto-loads model and optimizer state from `checkpoints/latest.pt`.
